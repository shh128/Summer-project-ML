# %%
# Fama & French 3 factors residual variance
# Note: Please use the latest version of pandas, this version should support returning to pd.Series after rolling
# To get a faster speed, we split the big dataframe into small ones
# Then using different process to calculate the variance
# We use 20 process to calculate variance, you can change the number of process according to your CPU situation
# You can use the following code to check your CPU situation
# import multiprocessing
# multiprocessing.cpu_count()

import pandas as pd
import numpy as np
import datetime as dt
import wrds
from dateutil.relativedelta import *
from pandas.tseries.offsets import *
import datetime
import pickle as pkl
import pyarrow.feather as feather
import multiprocessing as mp

# read the permno_list
permno_list = pd.read_csv('s&p500_permno.txt', header=None)
permno_list = tuple(permno_list.iloc[:,0].tolist())
###################
# Connect to WRDS #
###################
conn = wrds.Connection()

# CRSP Block
crsp = conn.raw_sql("""
                    select a.permno, a.date, a.vol, a.shrout
                    from crsp.dsf as a
                    where a.permno in {}
                    and a.date > '01/01/1959'
                    """.format(permno_list))

# sort variables by permno and date
crsp = crsp.sort_values(by=['permno', 'date'])

# change variable format to int
crsp['permno'] = crsp['permno'].astype(int)

# Line up date to be end of month
crsp['date'] = pd.to_datetime(crsp['date'])

# find the closest trading day to the end of the month
crsp['monthend'] = crsp['date'] + MonthEnd(0)
crsp['date_diff'] = crsp['monthend'] - crsp['date']
date_temp = crsp.groupby(['permno', 'monthend'])['date_diff'].min()
date_temp = pd.DataFrame(date_temp)  # convert Series to DataFrame
date_temp.reset_index(inplace=True)
date_temp.rename(columns={'date_diff': 'min_diff'}, inplace=True)
crsp = pd.merge(crsp, date_temp, how='left', on=['permno', 'monthend'])
crsp['sig'] = np.where(crsp['date_diff'] == crsp['min_diff'], 1, np.nan)

# label every date of month end
crsp['month_count'] = crsp[crsp['sig'] == 1].groupby(['permno']).cumcount()

# label numbers of months for a firm
month_num = crsp[crsp['sig'] == 1].groupby(['permno'])['month_count'].tail(1)
month_num = month_num.astype(int)
month_num = month_num.reset_index(drop=True)

# mark the number of each month to each day of this month
crsp['month_count'] = crsp.groupby(['permno'])['month_count'].fillna(method='bfill')

# crate a firm list
df_firm = crsp.drop_duplicates(['permno'])
df_firm = df_firm[['permno']]
df_firm['permno'] = df_firm['permno'].astype(int)
df_firm = df_firm.reset_index(drop=True)
df_firm = df_firm.reset_index()
df_firm = df_firm.rename(columns={'index': 'count'})
df_firm['month_num'] = month_num

######################
# Calculate residual #
######################


def get_baspread(df, firm_list):
    """

    :param df: stock dataframe
    :param firm_list: list of firms matching stock dataframe
    :return: dataframe with variance of residual
    """
    for firm, count, prog in zip(firm_list['permno'], firm_list['month_num'], range(firm_list['permno'].count()+1)):
        prog = prog + 1
        print('processing permno %s' % firm, '/', 'finished', '%.2f%%' % ((prog/firm_list['permno'].count())*100))
        for i in range(count + 1):
            # if you want to change the rolling window, please change here: i - 2 means 3 months is a window.
            temp = df[(df['permno'] == firm) & (i - 2 <= df['month_count']) & (df['month_count'] <= i)]
            if temp['permno'].count() < 21:
                pass
            else:
                index = temp.tail(1).index
                X = pd.DataFrame()
                X[['vol', 'shrout']] = temp[['vol', 'shrout']]
                X['countzero'] = np.where(X['vol'] == 0, 1, 0)
                X['turn'] = (X['vol'] / X['shrout'])
                X['turn'] = np.where(X['turn'] == 0, np.inf, X['turn'])
                zerotrade = (X['countzero']+((1/X['turn'])/480000))*21/X['vol'].count()
                df.loc[index, 'zerotrade'] = zerotrade
    return df


def sub_df(start, end, step):
    """

    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dictionary including all the 'firm_list' dataframe and 'stock data' dataframe
    """
    # we use dict to store different sub dataframe
    temp = {}
    for i, h in zip(np.arange(start, end, step), range(int((end-start)/step))):
        print('processing splitting dataframe:', round(i, 2), 'to', round(i + step, 2))
        if i == 0:  # to get the left point
            temp['firm' + str(h)] = df_firm[df_firm['count'] <= df_firm['count'].quantile(i + step)]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['count'])
        else:
            temp['firm' + str(h)] = df_firm[(df_firm['count'].quantile(i) < df_firm['count']) & (
                    df_firm['count'] <= df_firm['count'].quantile(i + step))]
            temp['crsp' + str(h)] = pd.merge(crsp, temp['firm' + str(h)], how='left',
                                             on='permno').dropna(subset=['count'])
    return temp


def main(start, end, step):
    """

    :param start: the quantile to start cutting, usually it should be 0
    :param end: the quantile to end cutting, usually it should be 1
    :param step: quantile step
    :return: a dataframe with calculated variance of residual
    """
    df = sub_df(start, end, step)
    pool = mp.Pool()
    p_dict = {}
    for i in range(int((end-start)/step)):
        p_dict['p' + str(i)] = pool.apply_async(get_baspread, (df['crsp%s' % i], df['firm%s' % i],))
    pool.close()
    pool.join()
    result = pd.DataFrame()
    print('processing pd.concat')
    for h in range(int((end-start)/step)):
        result = pd.concat([result, p_dict['p%s' % h].get()])
    return result


# calculate variance of residual through rolling window
# Note: please split dataframe according to your CPU situation. For example, we split dataframe to (1-0)/0.05 = 20 sub
# dataframes here, so the function will use 20 cores to calculate variance of residual.
if __name__ == '__main__':
    crsp = main(0, 1, 0.05)
# Out:
# Enter your WRDS username [root]:yupenglu
# Enter your password:··········
# WRDS recommends setting up a .pgpass file.
# Create .pgpass file now [y/n]?: y
# Created .pgpass file successfully.
# Loading library list...
# Done
# processing splitting dataframe: 0.0 to 0.05
# processing splitting dataframe: 0.05 to 0.1
# processing splitting dataframe: 0.1 to 0.15
# processing splitting dataframe: 0.15 to 0.2
# processing splitting dataframe: 0.2 to 0.25
# processing splitting dataframe: 0.25 to 0.3
# processing splitting dataframe: 0.3 to 0.35
# processing splitting dataframe: 0.35 to 0.4
# processing splitting dataframe: 0.4 to 0.45
# processing splitting dataframe: 0.45 to 0.5
# processing splitting dataframe: 0.5 to 0.55
# processing splitting dataframe: 0.55 to 0.6
# processing splitting dataframe: 0.6 to 0.65
# processing splitting dataframe: 0.65 to 0.7
# processing splitting dataframe: 0.7 to 0.75
# processing splitting dataframe: 0.75 to 0.8
# processing splitting dataframe: 0.8 to 0.85
# processing splitting dataframe: 0.85 to 0.9
# processing splitting dataframe: 0.9 to 0.95
# processing splitting dataframe: 0.95 to 1.0
# processing permno 10006 / finished 1.09%
# processing permno 11746 / finished 1.09%
# processing permno 11754 / finished 2.17%
# processing permno 10030 / finished 2.17%
# processing permno 10057 / finished 3.26%
# processing permno 11762 / finished 3.26%
# processing permno 10078 / finished 4.35%
# processing permno 10102 / finished 5.43%
# processing permno 10104 / finished 6.52%
# processing permno 11770 / finished 4.35%
# processing permno 11786 / finished 5.43%
# processing permno 10107 / finished 7.61%
# processing permno 11826 / finished 6.52%
# processing permno 11850 / finished 7.61%
# processing permno 10108 / finished 8.70%
# processing permno 10137 / finished 9.78%
# processing permno 11891 / finished 8.70%
# processing permno 10138 / finished 10.87%
# processing permno 11896 / finished 9.78%
# processing permno 10145 / finished 11.96%
# processing permno 11949 / finished 10.87%
# processing permno 11955 / finished 11.96%
# processing permno 10147 / finished 13.04%
# processing permno 11970 / finished 13.04%
# processing permno 11976 / finished 14.13%
# processing permno 10153 / finished 14.13%
# processing permno 11981 / finished 15.22%
# processing permno 10161 / finished 15.22%
# processing permno 11983 / finished 16.30%
# processing permno 11997 / finished 17.39%
# processing permno 10209 / finished 16.30%
# processing permno 10225 / finished 17.39%
# processing permno 12044 / finished 18.48%
# processing permno 12052 / finished 19.57%
# processing permno 10233 / finished 18.48%
# processing permno 10241 / finished 19.57%
# processing permno 12060 / finished 20.65%
# processing permno 10276 / finished 20.65%
# processing permno 10292 / finished 21.74%
# processing permno 10299 / finished 22.83%
# processing permno 10321 / finished 23.91%
# processing permno 12062 / finished 21.74%
# processing permno 10324 / finished 25.00%
# processing permno 12067 / finished 22.83%
# processing permno 10353 / finished 26.09%
# processing permno 12073 / finished 23.91%
# processing permno 10364 / finished 27.17%
# processing permno 12076 / finished 25.00%
# processing permno 12079 / finished 26.09%
# processing permno 10372 / finished 28.26%
# processing permno 10401 / finished 29.35%
# processing permno 12084 / finished 27.17%
# processing permno 12095 / finished 28.26%
# processing permno 10436 / finished 30.43%
# processing permno 10479 / finished 31.52%
# processing permno 12124 / finished 29.35%
# processing permno 12140 / finished 30.43%
# processing permno 10487 / finished 32.61%
# processing permno 10495 / finished 33.70%
# processing permno 12167 / finished 31.52%
# processing permno 10516 / finished 34.78%
# processing permno 12183 / finished 32.61%
# processing permno 12191 / finished 33.70%
# processing permno 12212 / finished 34.78%
# processing permno 12308 / finished 35.87%
# processing permno 12319 / finished 36.96%
# processing permno 10524 / finished 35.87%
# processing permno 10559 / finished 36.96%
# processing permno 12343 / finished 38.04%
# processing permno 10562 / finished 38.04%
# processing permno 12345 / finished 39.13%
# processing permno 12369 / finished 40.22%
# processing permno 10575 / finished 39.13%
# processing permno 12394 / finished 41.30%
# processing permno 10591 / finished 40.22%
# processing permno 12431 / finished 42.39%
# processing permno 10604 / finished 41.30%
# processing permno 10623 / finished 42.39%
# processing permno 12448 / finished 43.48%
# processing permno 10693 / finished 43.48%
# processing permno 12449 / finished 44.57%
# processing permno 12456 / finished 45.65%
# processing permno 12458 / finished 46.74%
# processing permno 10696 / finished 44.57%
# processing permno 12466 / finished 47.83%
# processing permno 10725 / finished 45.65%
# processing permno 10727 / finished 46.74%
# processing permno 12490 / finished 48.91%
# processing permno 10735 / finished 47.83%
# processing permno 10751 / finished 48.91%
# processing permno 10786 / finished 50.00%
# processing permno 12503 / finished 50.00%
# processing permno 10791 / finished 51.09%
# processing permno 10807 / finished 52.17%
# processing permno 12511 / finished 51.09%
# processing permno 10823 / finished 53.26%
# processing permno 10866 / finished 54.35%
# processing permno 12542 / finished 52.17%
# processing permno 12546 / finished 53.26%
# processing permno 12558 / finished 54.35%
# processing permno 10874 / finished 55.43%
# processing permno 12570 / finished 55.43%
# processing permno 10890 / finished 56.52%
# processing permno 12622 / finished 56.52%
# processing permno 12623 / finished 57.61%
# processing permno 12626 / finished 58.70%
# processing permno 12650 / finished 59.78%
# processing permno 10909 / finished 57.61%
# processing permno 10942 / finished 58.70%
# processing permno 12669 / finished 60.87%
# processing permno 10970 / finished 59.78%
# processing permno 12706 / finished 61.96%
# processing permno 10989 / finished 60.87%
# processing permno 12730 / finished 63.04%
# processing permno 12749 / finished 64.13%
# processing permno 11033 / finished 61.96%
# processing permno 11041 / finished 63.04%
# processing permno 12757 / finished 65.22%
# processing permno 12781 / finished 66.30%
# processing permno 11042 / finished 64.13%
# processing permno 11068 / finished 65.22%
# processing permno 11081 / finished 66.30%
# processing permno 11092 / finished 67.39%
# processing permno 12837 / finished 67.39%
# processing permno 11148 / finished 68.48%
# processing permno 12872 / finished 68.48%
# processing permno 11156 / finished 69.57%
# processing permno 12888 / finished 69.57%
# processing permno 11164 / finished 70.65%
# processing permno 12896 / finished 70.65%
# processing permno 11260 / finished 71.74%
# processing permno 12909 / finished 71.74%
# processing permno 12933 / finished 72.83%
# processing permno 11287 / finished 72.83%
# processing permno 12941 / finished 73.91%
# processing permno 12976 / finished 75.00%
# processing permno 11295 / finished 73.91%
# processing permno 12981 / finished 76.09%
# processing permno 11308 / finished 75.00%
# processing permno 13004 / finished 77.17%
# processing permno 13012 / finished 78.26%
# processing permno 13035 / finished 79.35%
# processing permno 13056 / finished 80.43%
# processing permno 11332 / finished 76.09%
# processing permno 13063 / finished 81.52%
# processing permno 11340 / finished 77.17%
# processing permno 13100 / finished 82.61%
# processing permno 11359 / finished 78.26%
# processing permno 11367 / finished 79.35%
# processing permno 11375 / finished 80.43%
# processing permno 13103 / finished 83.70%
# processing permno 11391 / finished 81.52%
# processing permno 11403 / finished 82.61%
# processing permno 13119 / finished 84.78%
# processing permno 11404 / finished 83.70%
# processing permno 13135 / finished 85.87%
# processing permno 13141 / finished 86.96%
# processing permno 13142 / finished 88.04%
# processing permno 13143 / finished 89.13%
# processing permno 11415 / finished 84.78%
# processing permno 11439 / finished 85.87%
# processing permno 13151 / finished 90.22%
# processing permno 13168 / finished 91.30%
# processing permno 11447 / finished 86.96%
# processing permno 13210 / finished 92.39%
# processing permno 13274 / finished 93.48%
# processing permno 13290 / finished 94.57%
# processing permno 11471 / finished 88.04%
# processing permno 11527 / finished 89.13%
# processing permno 11543 / finished 90.22%
# processing permno 13303 / finished 95.65%
# processing permno 11552 / finished 91.30%
# processing permno 11600 / finished 92.39%
# processing permno 13311 / finished 96.74%
# processing permno 11607 / finished 93.48%
# processing permno 13323 / finished 97.83%
# processing permno 13354 / finished 98.91%
# processing permno 11618 / finished 94.57%
# processing permno 13356 / finished 100.00%
# processing permno 13370 / finished 1.09%
# processing permno 11626 / finished 95.65%
# processing permno 11658 / finished 96.74%
# processing permno 13407 / finished 2.17%
# processing permno 13434 / finished 3.26%
# processing permno 11674 / finished 97.83%
# processing permno 13442 / finished 4.35%
# processing permno 13447 / finished 5.43%
# processing permno 13522 / finished 6.52%
# processing permno 13565 / finished 7.61%
# processing permno 13567 / finished 8.70%
# processing permno 13573 / finished 9.78%
# processing permno 11690 / finished 98.91%
# processing permno 13586 / finished 10.87%
# processing permno 13598 / finished 11.96%
# processing permno 13610 / finished 13.04%
# processing permno 11703 / finished 100.00%
# processing permno 13637 / finished 14.13%
# processing permno 15272 / finished 1.09%
# processing permno 15291 / finished 2.17%
# processing permno 13641 / finished 15.22%
# processing permno 15317 / finished 3.26%
# processing permno 13661 / finished 16.30%
# processing permno 15341 / finished 4.35%
# processing permno 15368 / finished 5.43%
# processing permno 13688 / finished 17.39%
# processing permno 15401 / finished 6.52%
# processing permno 15404 / finished 7.61%
# processing permno 15408 / finished 8.70%
# processing permno 15448 / finished 9.78%
# processing permno 15456 / finished 10.87%
# processing permno 13696 / finished 18.48%
# processing permno 13721 / finished 19.57%
# processing permno 13760 / finished 20.65%
# processing permno 13788 / finished 21.74%
# processing permno 15464 / finished 11.96%
# processing permno 13792 / finished 22.83%
# processing permno 15472 / finished 13.04%
# processing permno 13805 / finished 23.91%
# processing permno 13821 / finished 25.00%
# processing permno 15480 / finished 14.13%
# processing permno 15488 / finished 15.22%
# processing permno 15499 / finished 16.30%
# processing permno 13856 / finished 26.09%
# processing permno 15528 / finished 17.39%
# processing permno 15536 / finished 18.48%
# processing permno 15544 / finished 19.57%
# processing permno 15553 / finished 20.65%
# processing permno 13901 / finished 27.17%
# processing permno 15560 / finished 21.74%
# processing permno 13911 / finished 28.26%
# processing permno 15579 / finished 22.83%
# processing permno 13928 / finished 29.35%
# processing permno 15659 / finished 23.91%
# processing permno 13936 / finished 30.43%
# processing permno 15667 / finished 25.00%
# processing permno 13949 / finished 31.52%
# processing permno 13963 / finished 32.61%
# processing permno 13964 / finished 33.70%
# processing permno 15707 / finished 26.09%
# processing permno 15712 / finished 27.17%
# processing permno 13983 / finished 34.78%
# processing permno 14008 / finished 35.87%
# processing permno 15719 / finished 28.26%
# processing permno 15720 / finished 29.35%
# processing permno 14011 / finished 36.96%
# processing permno 14066 / finished 38.04%
# processing permno 14090 / finished 39.13%
# processing permno 15747 / finished 30.43%
# processing permno 14154 / finished 40.22%
# processing permno 15763 / finished 31.52%
# processing permno 14189 / finished 41.30%
# processing permno 15797 / finished 32.61%
# processing permno 15819 / finished 33.70%
# processing permno 15835 / finished 34.78%
# processing permno 15843 / finished 35.87%
# processing permno 14218 / finished 42.39%
# processing permno 15850 / finished 36.96%
# processing permno 14250 / finished 43.48%
# processing permno 15915 / finished 38.04%
# processing permno 14277 / finished 44.57%
# processing permno 15966 / finished 39.13%
# processing permno 15974 / finished 40.22%
# processing permno 14295 / finished 45.65%
# processing permno 14297 / finished 46.74%
# processing permno 15980 / finished 41.30%
# processing permno 14322 / finished 47.83%
# processing permno 16029 / finished 42.39%
# processing permno 16044 / finished 43.48%
# processing permno 16087 / finished 44.57%
# processing permno 16088 / finished 45.65%
# processing permno 14323 / finished 48.91%
# processing permno 16109 / finished 46.74%
# processing permno 14338 / finished 50.00%
# processing permno 14357 / finished 51.09%
# processing permno 16205 / finished 47.83%
# processing permno 16256 / finished 48.91%
# processing permno 16267 / finished 50.00%
# processing permno 16276 / finished 51.09%
# processing permno 16279 / finished 52.17%
# processing permno 14402 / finished 52.17%
# processing permno 16280 / finished 53.26%
# processing permno 16336 / finished 54.35%
# processing permno 14429 / finished 53.26%
# processing permno 14461 / finished 54.35%
# processing permno 16342 / finished 55.43%
# processing permno 16343 / finished 56.52%
# processing permno 16344 / finished 57.61%
# processing permno 16346 / finished 58.70%
# processing permno 16347 / finished 59.78%
# processing permno 16360 / finished 60.87%
# processing permno 14488 / finished 55.43%
# processing permno 16424 / finished 61.96%
# processing permno 14496 / finished 56.52%
# processing permno 14509 / finished 57.61%
# processing permno 16431 / finished 63.04%
# processing permno 16432 / finished 64.13%
# processing permno 14525 / finished 58.70%
# processing permno 14533 / finished 59.78%
# processing permno 14541 / finished 60.87%
# processing permno 16538 / finished 65.22%
# processing permno 16544 / finished 66.30%
# processing permno 16571 / finished 67.39%
# processing permno 16598 / finished 68.48%
# processing permno 14542 / finished 61.96%
# processing permno 16600 / finished 69.57%
# processing permno 14579 / finished 63.04%
# processing permno 14592 / finished 64.13%
# processing permno 14593 / finished 65.22%
# processing permno 16619 / finished 70.65%
# processing permno 16651 / finished 71.74%
# processing permno 14601 / finished 66.30%
# processing permno 14613 / finished 67.39%
# processing permno 14656 / finished 68.48%
# processing permno 16678 / finished 72.83%
# processing permno 14664 / finished 69.57%
# processing permno 16686 / finished 73.91%
# processing permno 14702 / finished 70.65%
# processing permno 16692 / finished 75.00%
# processing permno 16707 / finished 76.09%
# processing permno 16723 / finished 77.17%
# processing permno 16731 / finished 78.26%
# processing permno 14704 / finished 71.74%
# processing permno 14714 / finished 72.83%
# processing permno 14728 / finished 73.91%
# processing permno 16758 / finished 79.35%
# processing permno 14736 / finished 75.00%
# processing permno 16803 / finished 80.43%
# processing permno 16816 / finished 81.52%
# processing permno 14760 / finished 76.09%
# processing permno 16851 / finished 82.61%
# processing permno 16870 / finished 83.70%
# processing permno 14763 / finished 77.17%
# processing permno 14776 / finished 78.26%
# processing permno 14779 / finished 79.35%
# processing permno 14795 / finished 80.43%
# processing permno 16926 / finished 84.78%
# processing permno 16969 / finished 85.87%
# processing permno 17005 / finished 86.96%
# processing permno 14832 / finished 81.52%
# processing permno 14859 / finished 82.61%
# processing permno 14867 / finished 83.70%
# processing permno 17013 / finished 88.04%
# processing permno 17048 / finished 89.13%
# processing permno 17056 / finished 90.22%
# processing permno 14882 / finished 84.78%
# processing permno 17064 / finished 91.30%
# processing permno 17099 / finished 92.39%
# processing permno 14883 / finished 85.87%
# processing permno 17128 / finished 93.48%
# processing permno 17137 / finished 94.57%
# processing permno 14889 / finished 86.96%
# processing permno 14891 / finished 88.04%
# processing permno 17144 / finished 95.65%
# processing permno 14904 / finished 89.13%
# processing permno 14912 / finished 90.22%
# processing permno 14939 / finished 91.30%
# processing permno 17216 / finished 96.74%
# processing permno 17232 / finished 97.83%
# processing permno 15042 / finished 92.39%
# processing permno 15069 / finished 93.48%
# processing permno 17267 / finished 98.91%
# processing permno 17278 / finished 100.00%
# processing permno 17279 / finished 1.09%
# processing permno 17291 / finished 2.17%
# processing permno 15077 / finished 94.57%
# processing permno 17304 / finished 3.26%
# processing permno 17312 / finished 4.35%
# processing permno 17340 / finished 5.43%
# processing permno 15149 / finished 95.65%
# processing permno 15157 / finished 96.74%
# processing permno 17398 / finished 6.52%
# processing permno 17435 / finished 7.61%
# processing permno 15165 / finished 97.83%
# processing permno 15202 / finished 98.91%
# processing permno 17451 / finished 8.70%
# processing permno 17478 / finished 9.78%
# processing permno 15237 / finished 100.00%
# processing permno 19334 / finished 1.09%
# processing permno 17486 / finished 10.87%
# processing permno 17515 / finished 11.96%
# processing permno 19350 / finished 2.17%
# processing permno 17558 / finished 13.04%
# processing permno 17566 / finished 14.13%
# processing permno 17582 / finished 15.22%
# processing permno 17590 / finished 16.30%
# processing permno 19377 / finished 3.26%
# processing permno 17603 / finished 17.39%
# processing permno 17646 / finished 18.48%
# processing permno 19385 / finished 4.35%
# processing permno 17654 / finished 19.57%
# processing permno 19393 / finished 5.43%
# processing permno 17676 / finished 20.65%
# processing permno 17689 / finished 21.74%
# processing permno 17700 / finished 22.83%
# processing permno 17718 / finished 23.91%
# processing permno 17726 / finished 25.00%
# processing permno 19414 / finished 6.52%
# processing permno 17742 / finished 26.09%
# processing permno 19430 / finished 7.61%
# processing permno 17743 / finished 27.17%
# processing permno 19502 / finished 8.70%
# processing permno 17750 / finished 28.26%
# processing permno 19510 / finished 9.78%
# processing permno 19537 / finished 10.87%
# processing permno 17783 / finished 29.35%
# processing permno 17806 / finished 30.43%
# processing permno 19553 / finished 11.96%
# processing permno 17830 / finished 31.52%
# processing permno 19561 / finished 13.04%
# processing permno 17881 / finished 32.61%
# processing permno 17953 / finished 33.70%
# processing permno 19583 / finished 14.13%
# processing permno 19589 / finished 15.22%
# processing permno 17961 / finished 34.78%
# processing permno 19596 / finished 16.30%
# processing permno 18016 / finished 35.87%
# processing permno 19617 / finished 17.39%
# processing permno 19625 / finished 18.48%
# processing permno 19668 / finished 19.57%
# processing permno 19684 / finished 20.65%
# processing permno 19692 / finished 21.74%
# processing permno 18032 / finished 36.96%
# processing permno 18065 / finished 38.04%
# processing permno 18067 / finished 39.13%
# processing permno 19713 / finished 22.83%
# processing permno 19721 / finished 23.91%
# processing permno 18091 / finished 40.22%
# processing permno 18092 / finished 41.30%
# processing permno 19756 / finished 25.00%
# processing permno 19764 / finished 26.09%
# processing permno 18112 / finished 42.39%
# processing permno 19772 / finished 27.17%
# processing permno 19807 / finished 28.26%
# processing permno 19828 / finished 29.35%
# processing permno 18142 / finished 43.48%
# processing permno 18143 / finished 44.57%
# processing permno 18147 / finished 45.65%
# processing permno 18163 / finished 46.74%
# processing permno 19836 / finished 30.43%
# processing permno 19844 / finished 31.52%
# processing permno 19879 / finished 32.61%
# processing permno 19887 / finished 33.70%
# processing permno 18278 / finished 47.83%
# processing permno 19895 / finished 34.78%
# processing permno 18312 / finished 48.91%
# processing permno 18315 / finished 50.00%
# processing permno 19916 / finished 35.87%
# processing permno 18327 / finished 51.09%
# processing permno 18331 / finished 52.17%
# processing permno 18366 / finished 53.26%
# processing permno 18374 / finished 54.35%
# processing permno 19932 / finished 36.96%
# processing permno 19940 / finished 38.04%
# processing permno 19967 / finished 39.13%
# processing permno 18382 / finished 55.43%
# processing permno 20001 / finished 40.22%
# processing permno 20036 / finished 41.30%
# processing permno 20053 / finished 42.39%
# processing permno 18390 / finished 56.52%
# processing permno 18403 / finished 57.61%
# processing permno 20057 / finished 43.48%
# processing permno 20079 / finished 44.57%
# processing permno 20095 / finished 45.65%
# processing permno 18411 / finished 58.70%
# processing permno 20124 / finished 46.74%
# processing permno 18420 / finished 59.78%
# processing permno 20167 / finished 47.83%
# processing permno 18421 / finished 60.87%
# processing permno 18428 / finished 61.96%
# processing permno 18446 / finished 63.04%
# processing permno 20191 / finished 48.91%
# processing permno 20204 / finished 50.00%
# processing permno 18454 / finished 64.13%
# processing permno 18542 / finished 65.22%
# processing permno 20220 / finished 51.09%
# processing permno 18550 / finished 66.30%
# processing permno 18551 / finished 67.39%
# processing permno 20239 / finished 52.17%
# processing permno 18569 / finished 68.48%
# processing permno 20263 / finished 53.26%
# processing permno 18578 / finished 69.57%
# processing permno 18585 / finished 70.65%
# processing permno 20298 / finished 54.35%
# processing permno 20343 / finished 55.43%
# processing permno 18592 / finished 71.74%
# processing permno 18649 / finished 72.83%
# processing permno 20386 / finished 56.52%
# processing permno 20394 / finished 57.61%
# processing permno 18681 / finished 73.91%
# processing permno 20407 / finished 58.70%
# processing permno 18724 / finished 75.00%
# processing permno 18729 / finished 76.09%
# processing permno 20415 / finished 59.78%
# processing permno 18825 / finished 77.17%
# processing permno 18841 / finished 78.26%
# processing permno 20431 / finished 60.87%
# processing permno 18884 / finished 79.35%
# processing permno 20474 / finished 61.96%
# processing permno 18921 / finished 80.43%
# processing permno 20482 / finished 63.04%
# processing permno 18948 / finished 81.52%
# processing permno 20503 / finished 64.13%
# processing permno 18980 / finished 82.61%
# processing permno 20511 / finished 65.22%
# processing permno 20562 / finished 66.30%
# processing permno 18999 / finished 83.70%
# processing permno 20570 / finished 67.39%
# processing permno 19019 / finished 84.78%
# processing permno 20626 / finished 68.48%
# processing permno 19027 / finished 85.87%
# processing permno 19051 / finished 86.96%
# processing permno 20677 / finished 69.57%
# processing permno 19107 / finished 88.04%
# processing permno 20714 / finished 70.65%
# processing permno 19131 / finished 89.13%
# processing permno 20730 / finished 71.74%
# processing permno 19166 / finished 90.22%
# processing permno 20853 / finished 72.83%
# processing permno 19174 / finished 91.30%
# processing permno 20896 / finished 73.91%
# processing permno 20909 / finished 75.00%
# processing permno 19203 / finished 92.39%
# processing permno 19211 / finished 93.48%
# processing permno 19238 / finished 94.57%
# processing permno 20976 / finished 76.09%
# processing permno 19254 / finished 95.65%
# processing permno 20984 / finished 77.17%
# processing permno 20992 / finished 78.26%
# processing permno 19270 / finished 96.74%
# processing permno 19285 / finished 97.83%
# processing permno 19286 / finished 98.91%
# processing permno 19297 / finished 100.00%
# processing permno 21004 / finished 79.35%
# processing permno 21397 / finished 1.09%
# processing permno 21020 / finished 80.43%
# processing permno 21418 / finished 2.17%
# processing permno 21426 / finished 3.26%
# processing permno 21434 / finished 4.35%
# processing permno 21450 / finished 5.43%
# processing permno 21055 / finished 81.52%
# processing permno 21469 / finished 6.52%
# processing permno 21485 / finished 7.61%
# processing permno 21514 / finished 8.70%
# processing permno 21119 / finished 82.61%
# processing permno 21124 / finished 83.70%
# processing permno 21151 / finished 84.78%
# processing permno 21522 / finished 9.78%
# processing permno 21178 / finished 85.87%
# processing permno 21530 / finished 10.87%
# processing permno 21549 / finished 11.96%
# processing permno 21557 / finished 13.04%
# processing permno 21186 / finished 86.96%
# processing permno 21573 / finished 14.13%
# processing permno 21194 / finished 88.04%
# processing permno 21645 / finished 15.22%
# processing permno 21709 / finished 16.30%
# processing permno 21207 / finished 89.13%
# processing permno 21768 / finished 17.39%
# processing permno 21776 / finished 18.48%
# processing permno 21231 / finished 90.22%
# processing permno 21784 / finished 19.57%
# processing permno 21792 / finished 20.65%
# processing permno 21266 / finished 91.30%
# processing permno 21274 / finished 92.39%
# processing permno 21282 / finished 93.48%
# processing permno 21821 / finished 21.74%
# processing permno 21290 / finished 94.57%
# processing permno 21901 / finished 22.83%
# processing permno 21928 / finished 23.91%
# processing permno 21303 / finished 95.65%
# processing permno 21338 / finished 96.74%
# processing permno 21936 / finished 25.00%
# processing permno 21346 / finished 97.83%
# processing permno 21370 / finished 98.91%
# processing permno 21979 / finished 26.09%
# processing permno 21371 / finished 100.00%
# processing permno 21995 / finished 27.17%
# processing permno 23318 / finished 1.09%
# processing permno 22007 / finished 28.26%
# processing permno 23325 / finished 2.17%
# processing permno 22015 / finished 29.35%
# processing permno 22023 / finished 30.43%
# processing permno 23341 / finished 3.26%
# processing permno 22032 / finished 31.52%
# processing permno 23384 / finished 4.35%
# processing permno 23393 / finished 5.43%
# processing permno 22066 / finished 32.61%
# processing permno 23421 / finished 6.52%
# processing permno 22074 / finished 33.70%
# processing permno 23448 / finished 7.61%
# processing permno 22082 / finished 34.78%
# processing permno 23456 / finished 8.70%
# processing permno 23464 / finished 9.78%
# processing permno 22103 / finished 35.87%
# processing permno 23473 / finished 10.87%
# processing permno 23480 / finished 11.96%
# processing permno 22111 / finished 36.96%
# processing permno 23499 / finished 13.04%
# processing permno 23501 / finished 14.13%
# processing permno 22138 / finished 38.04%
# processing permno 22170 / finished 39.13%
# processing permno 23528 / finished 15.22%
# processing permno 23536 / finished 16.30%
# processing permno 22189 / finished 40.22%
# processing permno 22218 / finished 41.30%
# processing permno 22242 / finished 42.39%
# processing permno 22250 / finished 43.48%
# processing permno 23552 / finished 17.39%
# processing permno 22293 / finished 44.57%
# processing permno 23579 / finished 18.48%
# processing permno 22306 / finished 45.65%
# processing permno 23587 / finished 19.57%
# processing permno 22330 / finished 46.74%
# processing permno 22365 / finished 47.83%
# processing permno 23616 / finished 20.65%
# processing permno 22381 / finished 48.91%
# processing permno 23660 / finished 21.74%
# processing permno 22402 / finished 50.00%
# processing permno 22410 / finished 51.09%
# processing permno 22429 / finished 52.17%
# processing permno 23683 / finished 22.83%
# processing permno 22461 / finished 53.26%
# processing permno 23712 / finished 23.91%
# processing permno 22488 / finished 54.35%
# processing permno 22496 / finished 55.43%
# processing permno 23720 / finished 25.00%
# processing permno 22509 / finished 56.52%
# processing permno 23800 / finished 26.09%
# processing permno 23819 / finished 27.17%
# processing permno 22517 / finished 57.61%
# processing permno 23851 / finished 28.26%
# processing permno 22533 / finished 58.70%
# processing permno 22541 / finished 59.78%
# processing permno 23878 / finished 29.35%
# processing permno 23886 / finished 30.43%
# processing permno 23887 / finished 31.52%
# processing permno 22568 / finished 60.87%
# processing permno 22592 / finished 61.96%
# processing permno 23894 / finished 32.61%
# processing permno 23907 / finished 33.70%
# processing permno 23915 / finished 34.78%
# processing permno 22613 / finished 63.04%
# processing permno 23931 / finished 35.87%
# processing permno 22623 / finished 64.13%
# processing permno 22648 / finished 65.22%
# processing permno 22680 / finished 66.30%
# processing permno 23990 / finished 36.96%
# processing permno 22699 / finished 67.39%
# processing permno 22728 / finished 68.48%
# processing permno 24002 / finished 38.04%
# processing permno 22752 / finished 69.57%
# processing permno 24010 / finished 39.13%
# processing permno 22753 / finished 70.65%
# processing permno 24037 / finished 40.22%
# processing permno 22760 / finished 71.74%
# processing permno 24046 / finished 41.30%
# processing permno 24053 / finished 42.39%
# processing permno 22779 / finished 72.83%
# processing permno 22787 / finished 73.91%
# processing permno 24061 / finished 43.48%
# processing permno 24088 / finished 44.57%
# processing permno 24096 / finished 45.65%
# processing permno 22808 / finished 75.00%
# processing permno 22840 / finished 76.09%
# processing permno 24109 / finished 46.74%
# processing permno 22859 / finished 77.17%
# processing permno 24141 / finished 47.83%
# processing permno 22875 / finished 78.26%
# processing permno 22891 / finished 79.35%
# processing permno 24176 / finished 48.91%
# processing permno 24184 / finished 50.00%
# processing permno 22920 / finished 80.43%
# processing permno 22939 / finished 81.52%
# processing permno 24192 / finished 51.09%
# processing permno 22947 / finished 82.61%
# processing permno 24205 / finished 52.17%
# processing permno 23018 / finished 83.70%
# processing permno 23026 / finished 84.78%
# processing permno 24221 / finished 53.26%
# processing permno 23050 / finished 85.87%
# processing permno 24264 / finished 54.35%
# processing permno 23077 / finished 86.96%
# processing permno 24272 / finished 55.43%
# processing permno 23085 / finished 88.04%
# processing permno 24328 / finished 56.52%
# processing permno 23114 / finished 89.13%
# processing permno 23130 / finished 90.22%
# processing permno 24336 / finished 57.61%
# processing permno 23165 / finished 91.30%
# processing permno 23210 / finished 92.39%
# processing permno 24360 / finished 58.70%
# processing permno 23229 / finished 93.48%
# processing permno 24387 / finished 59.78%
# processing permno 24459 / finished 60.87%
# processing permno 23237 / finished 94.57%
# processing permno 23253 / finished 95.65%
# processing permno 24504 / finished 61.96%
# processing permno 23288 / finished 96.74%
# processing permno 24539 / finished 63.04%
# processing permno 23296 / finished 97.83%
# processing permno 23309 / finished 98.91%
# processing permno 24555 / finished 64.13%
# processing permno 24563 / finished 65.22%
# processing permno 23317 / finished 100.00%
# processing permno 24571 / finished 66.30%
# processing permno 25267 / finished 1.09%
# processing permno 24619 / finished 67.39%
# processing permno 24627 / finished 68.48%
# processing permno 25320 / finished 2.17%
# processing permno 24635 / finished 69.57%
# processing permno 24643 / finished 70.65%
# processing permno 25339 / finished 3.26%
# processing permno 25371 / finished 4.35%
# processing permno 24651 / finished 71.74%
# processing permno 25419 / finished 5.43%
# processing permno 24678 / finished 72.83%
# processing permno 24707 / finished 73.91%
# processing permno 25478 / finished 6.52%
# processing permno 24715 / finished 75.00%
# processing permno 25487 / finished 7.61%
# processing permno 24766 / finished 76.09%
# processing permno 25507 / finished 8.70%
# processing permno 25515 / finished 9.78%
# processing permno 24803 / finished 77.17%
# processing permno 25574 / finished 10.87%
# processing permno 25582 / finished 11.96%
# processing permno 24811 / finished 78.26%
# processing permno 25590 / finished 13.04%
# processing permno 24854 / finished 79.35%
# processing permno 24889 / finished 80.43%
# processing permno 24942 / finished 81.52%
# processing permno 25611 / finished 14.13%
# processing permno 25646 / finished 15.22%
# processing permno 24985 / finished 82.61%
# processing permno 25662 / finished 16.30%
# processing permno 25670 / finished 17.39%
# processing permno 25689 / finished 18.48%
# processing permno 24993 / finished 83.70%
# processing permno 25005 / finished 84.78%
# processing permno 25697 / finished 19.57%
# processing permno 25013 / finished 85.87%
# processing permno 25718 / finished 20.65%
# processing permno 25742 / finished 21.74%
# processing permno 25769 / finished 22.83%
# processing permno 25022 / finished 86.96%
# processing permno 25056 / finished 88.04%
# processing permno 25778 / finished 23.91%
# processing permno 25072 / finished 89.13%
# processing permno 25785 / finished 25.00%
# processing permno 25081 / finished 90.22%
# processing permno 25873 / finished 26.09%
# processing permno 25099 / finished 91.30%
# processing permno 25902 / finished 27.17%
# processing permno 25910 / finished 28.26%
# processing permno 25128 / finished 92.39%
# processing permno 25953 / finished 29.35%
# processing permno 25144 / finished 93.48%
# processing permno 25160 / finished 94.57%
# processing permno 25988 / finished 30.43%
# processing permno 25179 / finished 95.65%
# processing permno 25187 / finished 96.74%
# processing permno 25195 / finished 97.83%
# processing permno 26075 / finished 31.52%
# processing permno 25216 / finished 98.91%
# processing permno 25232 / finished 100.00%
# processing permno 26112 / finished 32.61%
# processing permno 26120 / finished 33.70%
# processing permno 27836 / finished 1.09%
# processing permno 26155 / finished 34.78%
# processing permno 26286 / finished 35.87%
# processing permno 27852 / finished 2.17%
# processing permno 27879 / finished 3.26%
# processing permno 26294 / finished 36.96%
# processing permno 27887 / finished 4.35%
# processing permno 26307 / finished 38.04%
# processing permno 26323 / finished 39.13%
# processing permno 26332 / finished 40.22%
# processing permno 27916 / finished 5.43%
# processing permno 27924 / finished 6.52%
# processing permno 26366 / finished 41.30%
# processing permno 26382 / finished 42.39%
# processing permno 27940 / finished 7.61%
# processing permno 27959 / finished 8.70%
# processing permno 26390 / finished 43.48%
# processing permno 26403 / finished 44.57%
# processing permno 27983 / finished 9.78%
# processing permno 26438 / finished 45.65%
# processing permno 27991 / finished 10.87%
# processing permno 26446 / finished 46.74%
# processing permno 26462 / finished 47.83%
# processing permno 26497 / finished 48.91%
# processing permno 28003 / finished 11.96%
# processing permno 28089 / finished 13.04%
# processing permno 26518 / finished 50.00%
# processing permno 28118 / finished 14.13%
# processing permno 26534 / finished 51.09%
# processing permno 28134 / finished 15.22%
# processing permno 26542 / finished 52.17%
# processing permno 28169 / finished 16.30%
# processing permno 26550 / finished 53.26%
# processing permno 28177 / finished 17.39%
# processing permno 28222 / finished 18.48%
# processing permno 26569 / finished 54.35%
# processing permno 26622 / finished 55.43%
# processing permno 28265 / finished 19.57%
# processing permno 26649 / finished 56.52%
# processing permno 28281 / finished 20.65%
# processing permno 28310 / finished 21.74%
# processing permno 26657 / finished 57.61%
# processing permno 28345 / finished 22.83%
# processing permno 26681 / finished 58.70%
# processing permno 28353 / finished 23.91%
# processing permno 26710 / finished 59.78%
# processing permno 28388 / finished 25.00%
# processing permno 26729 / finished 60.87%
# processing permno 28433 / finished 26.09%
# processing permno 26737 / finished 61.96%
# processing permno 28484 / finished 27.17%
# processing permno 26788 / finished 63.04%
# processing permno 26825 / finished 64.13%
# processing permno 28505 / finished 28.26%
# processing permno 28513 / finished 29.35%
# processing permno 28548 / finished 30.43%
# processing permno 26884 / finished 65.22%
# processing permno 28580 / finished 31.52%
# processing permno 28804 / finished 32.61%
# processing permno 26921 / finished 66.30%
# processing permno 27000 / finished 67.39%
# processing permno 28847 / finished 33.70%
# processing permno 27027 / finished 68.48%
# processing permno 27043 / finished 69.57%
# processing permno 28994 / finished 34.78%
# processing permno 29102 / finished 35.87%
# processing permno 27051 / finished 70.65%
# processing permno 29196 / finished 36.96%
# processing permno 27086 / finished 71.74%
# processing permno 29911 / finished 38.04%
# processing permno 29946 / finished 39.13%
# processing permno 27087 / finished 72.83%
# processing permno 27115 / finished 73.91%
# processing permno 27158 / finished 75.00%
# processing permno 29962 / finished 40.22%
# processing permno 27174 / finished 76.09%
# processing permno 30067 / finished 41.30%
# processing permno 30330 / finished 42.39%
# processing permno 27182 / finished 77.17%
# processing permno 27190 / finished 78.26%
# processing permno 30365 / finished 43.48%
# processing permno 27238 / finished 79.35%
# processing permno 30382 / finished 44.57%
# processing permno 27263 / finished 80.43%
# processing permno 30681 / finished 45.65%
# processing permno 27297 / finished 81.52%
# processing permno 27342 / finished 82.61%
# processing permno 30912 / finished 46.74%
# processing permno 27422 / finished 83.70%
# processing permno 30940 / finished 47.83%
# processing permno 27430 / finished 84.78%
# processing permno 31536 / finished 48.91%
# processing permno 31659 / finished 50.00%
# processing permno 27465 / finished 85.87%
# processing permno 31763 / finished 51.09%
# processing permno 27473 / finished 86.96%
# processing permno 32141 / finished 52.17%
# processing permno 27510 / finished 88.04%
# processing permno 32205 / finished 53.26%
# processing permno 27537 / finished 89.13%
# processing permno 27561 / finished 90.22%
# processing permno 27596 / finished 91.30%
# processing permno 32379 / finished 54.35%
# processing permno 27617 / finished 92.39%
# processing permno 32475 / finished 55.43%
# processing permno 32563 / finished 56.52%
# processing permno 27633 / finished 93.48%
# processing permno 32707 / finished 57.61%
# processing permno 27713 / finished 94.57%
# processing permno 32791 / finished 58.70%
# processing permno 27748 / finished 95.65%
# processing permno 32803 / finished 59.78%
# processing permno 27749 / finished 96.74%
# processing permno 27756 / finished 97.83%
# processing permno 32870 / finished 60.87%
# processing permno 27764 / finished 98.91%
# processing permno 32986 / finished 61.96%
# processing permno 27828 / finished 100.00%
# processing permno 33056 / finished 63.04%
# processing permno 33312 / finished 64.13%
# processing permno 38280 / finished 1.10%
# processing permno 33785 / finished 65.22%
# processing permno 38324 / finished 2.20%
# processing permno 38404 / finished 3.30%
# processing permno 38455 / finished 4.40%
# processing permno 33814 / finished 66.30%
# processing permno 38551 / finished 5.49%
# processing permno 33873 / finished 67.39%
# processing permno 38578 / finished 6.59%
# processing permno 34024 / finished 68.48%
# processing permno 34032 / finished 69.57%
# processing permno 38682 / finished 7.69%
# processing permno 34040 / finished 70.65%
# processing permno 38703 / finished 8.79%
# processing permno 34147 / finished 71.74%
# processing permno 34550 / finished 72.83%
# processing permno 38762 / finished 9.89%
# processing permno 34746 / finished 73.91%
# processing permno 34817 / finished 75.00%
# processing permno 38850 / finished 10.99%
# processing permno 38885 / finished 12.09%
# processing permno 34833 / finished 76.09%
# processing permno 38893 / finished 13.19%
# processing permno 38914 / finished 14.29%
# processing permno 34841 / finished 77.17%
# processing permno 35044 / finished 78.26%
# processing permno 38930 / finished 15.38%
# processing permno 38973 / finished 16.48%
# processing permno 35051 / finished 79.35%
# processing permno 39087 / finished 17.58%
# processing permno 35166 / finished 80.43%
# processing permno 39140 / finished 18.68%
# processing permno 35211 / finished 81.52%
# processing permno 39263 / finished 19.78%
# processing permno 39271 / finished 20.88%
# processing permno 35238 / finished 82.61%
# processing permno 39300 / finished 21.98%
# processing permno 39335 / finished 23.08%
# processing permno 35554 / finished 83.70%
# processing permno 39394 / finished 24.18%
# processing permno 39458 / finished 25.27%
# processing permno 36003 / finished 84.78%
# processing permno 39490 / finished 26.37%
# processing permno 39538 / finished 27.47%
# processing permno 36127 / finished 85.87%
# processing permno 36397 / finished 86.96%
# processing permno 39626 / finished 28.57%
# processing permno 39642 / finished 29.67%
# processing permno 36468 / finished 88.04%
# processing permno 39669 / finished 30.77%
# processing permno 36469 / finished 89.13%
# processing permno 39765 / finished 31.87%
# processing permno 36505 / finished 90.22%
# processing permno 36978 / finished 91.30%
# processing permno 39896 / finished 32.97%
# processing permno 39917 / finished 34.07%
# processing permno 37065 / finished 92.39%
# processing permno 37102 / finished 93.48%
# processing permno 39992 / finished 35.16%
# processing permno 40010 / finished 36.26%
# processing permno 37161 / finished 94.57%
# processing permno 40053 / finished 37.36%
# processing permno 40061 / finished 38.46%
# processing permno 37284 / finished 95.65%
# processing permno 40125 / finished 39.56%
# processing permno 37584 / finished 96.74%
# processing permno 40141 / finished 40.66%
# processing permno 38041 / finished 97.83%
# processing permno 40221 / finished 41.76%
# processing permno 38093 / finished 98.91%
# processing permno 40272 / finished 42.86%
# processing permno 38156 / finished 100.00%
# processing permno 40301 / finished 43.96%
# processing permno 43123 / finished 1.09%
# processing permno 40352 / finished 45.05%
# processing permno 40416 / finished 46.15%
# processing permno 43132 / finished 2.17%
# processing permno 43203 / finished 3.26%
# processing permno 43298 / finished 4.35%
# processing permno 40432 / finished 47.25%
# processing permno 40483 / finished 48.35%
# processing permno 43318 / finished 5.43%
# processing permno 43342 / finished 6.52%
# processing permno 40484 / finished 49.45%
# processing permno 43350 / finished 7.61%
# processing permno 40539 / finished 50.55%
# processing permno 43449 / finished 8.70%
# processing permno 40635 / finished 51.65%
# processing permno 40723 / finished 52.75%
# processing permno 40758 / finished 53.85%
# processing permno 43502 / finished 9.78%
# processing permno 40790 / finished 54.95%
# processing permno 43510 / finished 10.87%
# processing permno 40838 / finished 56.04%
# processing permno 43553 / finished 11.96%
# processing permno 40854 / finished 57.14%
# processing permno 41080 / finished 58.24%
# processing permno 43609 / finished 13.04%
# processing permno 43610 / finished 14.13%
# processing permno 43633 / finished 15.22%
# processing permno 43772 / finished 16.30%
# processing permno 41081 / finished 59.34%
# processing permno 41160 / finished 60.44%
# processing permno 41179 / finished 61.54%
# processing permno 43916 / finished 17.39%
# processing permno 41355 / finished 62.64%
# processing permno 44062 / finished 18.48%
# processing permno 44206 / finished 19.57%
# processing permno 41427 / finished 63.74%
# processing permno 41443 / finished 64.84%
# processing permno 44273 / finished 20.65%
# processing permno 44329 / finished 21.74%
# processing permno 41478 / finished 65.93%
# processing permno 41486 / finished 67.03%
# processing permno 44505 / finished 22.83%
# processing permno 41515 / finished 68.13%
# processing permno 44601 / finished 23.91%
# processing permno 41523 / finished 69.23%
# processing permno 41662 / finished 70.33%
# processing permno 44644 / finished 25.00%
# processing permno 41718 / finished 71.43%
# processing permno 41785 / finished 72.53%
# processing permno 41929 / finished 73.63%
# processing permno 44652 / finished 26.09%
# processing permno 44792 / finished 27.17%
# processing permno 41953 / finished 74.73%
# processing permno 44951 / finished 28.26%
# processing permno 42024 / finished 75.82%
# processing permno 45014 / finished 29.35%
# processing permno 42075 / finished 76.92%
# processing permno 45065 / finished 30.43%
# processing permno 42083 / finished 78.02%
# processing permno 45081 / finished 31.52%
# processing permno 45225 / finished 32.61%
# processing permno 42091 / finished 79.12%
# processing permno 42104 / finished 80.22%
# processing permno 45241 / finished 33.70%
# processing permno 42200 / finished 81.32%
# processing permno 45277 / finished 34.78%
# processing permno 42235 / finished 82.42%
# processing permno 45356 / finished 35.87%
# processing permno 42323 / finished 83.52%
# processing permno 42462 / finished 84.62%
# processing permno 42526 / finished 85.71%
# processing permno 45428 / finished 36.96%
# processing permno 42534 / finished 86.81%
# processing permno 45495 / finished 38.04%
# processing permno 42550 / finished 87.91%
# processing permno 45604 / finished 39.13%
# processing permno 45620 / finished 40.22%
# processing permno 42569 / finished 89.01%
# processing permno 45663 / finished 41.30%
# processing permno 45671 / finished 42.39%
# processing permno 42585 / finished 90.11%
# processing permno 45751 / finished 43.48%
# processing permno 42606 / finished 91.21%
# processing permno 45794 / finished 44.57%
# processing permno 42657 / finished 92.31%
# processing permno 42753 / finished 93.41%
# processing permno 45911 / finished 45.65%
# processing permno 42796 / finished 94.51%
# processing permno 45970 / finished 46.74%
# processing permno 42833 / finished 95.60%
# processing permno 46201 / finished 47.83%
# processing permno 46228 / finished 48.91%
# processing permno 42877 / finished 96.70%
# processing permno 46252 / finished 50.00%
# processing permno 46288 / finished 51.09%
# processing permno 42906 / finished 97.80%
# processing permno 46295 / finished 52.17%
# processing permno 42999 / finished 98.90%
# processing permno 46391 / finished 53.26%
# processing permno 43094 / finished 100.00%
# processing permno 48514 / finished 1.09%
# processing permno 46447 / finished 54.35%
# processing permno 46544 / finished 55.43%
# processing permno 46578 / finished 56.52%
# processing permno 48549 / finished 2.17%
# processing permno 48565 / finished 3.26%
# processing permno 48653 / finished 4.35%
# processing permno 46594 / finished 57.61%
# processing permno 46615 / finished 58.70%
# processing permno 48725 / finished 5.43%
# processing permno 46658 / finished 59.78%
# processing permno 46674 / finished 60.87%
# processing permno 48960 / finished 6.52%
# processing permno 46682 / finished 61.96%
# processing permno 49015 / finished 7.61%
# processing permno 46703 / finished 63.04%
# processing permno 49154 / finished 8.70%
# processing permno 46754 / finished 64.13%
# processing permno 46850 / finished 65.22%
# processing permno 49373 / finished 9.78%
# processing permno 46877 / finished 66.30%
# processing permno 49429 / finished 10.87%
# processing permno 46886 / finished 67.39%
# processing permno 46922 / finished 68.48%
# processing permno 49592 / finished 11.96%
# processing permno 49606 / finished 13.04%
# processing permno 49656 / finished 14.13%
# processing permno 47028 / finished 69.57%
# processing permno 47052 / finished 70.65%
# processing permno 49680 / finished 15.22%
# processing permno 47079 / finished 71.74%
# processing permno 47159 / finished 72.83%
# processing permno 49744 / finished 16.30%
# processing permno 47175 / finished 73.91%
# processing permno 49905 / finished 17.39%
# processing permno 47271 / finished 75.00%
# processing permno 49920 / finished 18.48%
# processing permno 47300 / finished 76.09%
# processing permno 49955 / finished 19.57%
# processing permno 47386 / finished 77.17%
# processing permno 47466 / finished 78.26%
# processing permno 50017 / finished 20.65%
# processing permno 50024 / finished 21.74%
# processing permno 47482 / finished 79.35%
# processing permno 47490 / finished 80.43%
# processing permno 50032 / finished 22.83%
# processing permno 47562 / finished 81.52%
# processing permno 47626 / finished 82.61%
# processing permno 50156 / finished 23.91%
# processing permno 50200 / finished 25.00%
# processing permno 50227 / finished 26.09%
# processing permno 47837 / finished 83.70%
# processing permno 47896 / finished 84.78%
# processing permno 50403 / finished 27.17%
# processing permno 50404 / finished 28.26%
# processing permno 47941 / finished 85.87%
# processing permno 50534 / finished 29.35%
# processing permno 50681 / finished 30.43%
# processing permno 50737 / finished 31.52%
# ...
# processing permno 76887 / finished 78.26%
# processing permno 77976 / finished 9.78%
# processing permno 77037 / finished 79.35%
# processing permno 78034 / finished 10.87%
# processing permno 77063 / finished 80.43%
# processing permno 78083 / finished 11.96%
# processing permno 77129 / finished 81.52%
# processing permno 78139 / finished 13.04%
# processing permno 77150 / finished 82.61%
# processing permno 78263 / finished 14.13%
# processing permno 77157 / finished 83.70%
# processing permno 78788 / finished 15.22%
# processing permno 78840 / finished 16.30%
# processing permno 77173 / finished 84.78%
# processing permno 78877 / finished 17.39%
# processing permno 77178 / finished 85.87%
# processing permno 78916 / finished 18.48%
# processing permno 77182 / finished 86.96%
# processing permno 78927 / finished 19.57%
# processing permno 77274 / finished 88.04%
# processing permno 78946 / finished 20.65%
# processing permno 78968 / finished 21.74%
# processing permno 77281 / finished 89.13%
# processing permno 78975 / finished 22.83%
# processing permno 77284 / finished 90.22%
# processing permno 77338 / finished 91.30%
# processing permno 78987 / finished 23.91%
# processing permno 77357 / finished 92.39%
# processing permno 79041 / finished 25.00%
# processing permno 79057 / finished 26.09%
# processing permno 77418 / finished 93.48%
# processing permno 79089 / finished 27.17%
# processing permno 77462 / finished 94.57%
# processing permno 79094 / finished 28.26%
# processing permno 77481 / finished 95.65%
# processing permno 79103 / finished 29.35%
# processing permno 77496 / finished 96.74%
# processing permno 79108 / finished 30.43%
# processing permno 77546 / finished 97.83%
# processing permno 77605 / finished 98.91%
# processing permno 79119 / finished 31.52%
# processing permno 79129 / finished 32.61%
# processing permno 77606 / finished 100.00%
# processing permno 79145 / finished 33.70%
# processing permno 81696 / finished 1.09%
# processing permno 79212 / finished 34.78%
# processing permno 81736 / finished 2.17%
# processing permno 79237 / finished 35.87%
# processing permno 81774 / finished 3.26%
# processing permno 79250 / finished 36.96%
# processing permno 81776 / finished 4.35%
# processing permno 79265 / finished 38.04%
# processing permno 81857 / finished 5.43%
# processing permno 79323 / finished 39.13%
# processing permno 82196 / finished 6.52%
# processing permno 82298 / finished 7.61%
# processing permno 79411 / finished 40.22%
# processing permno 79545 / finished 41.30%
# processing permno 82303 / finished 8.70%
# processing permno 82307 / finished 9.78%
# processing permno 79547 / finished 42.39%
# processing permno 82308 / finished 10.87%
# processing permno 82309 / finished 11.96%
# processing permno 79588 / finished 43.48%
# processing permno 82515 / finished 13.04%
# processing permno 79637 / finished 44.57%
# processing permno 82581 / finished 14.13%
# processing permno 82598 / finished 15.22%
# processing permno 79678 / finished 45.65%
# processing permno 82618 / finished 16.30%
# processing permno 79698 / finished 46.74%
# processing permno 82642 / finished 17.39%
# processing permno 79718 / finished 47.83%
# processing permno 82643 / finished 18.48%
# processing permno 79764 / finished 48.91%
# processing permno 79782 / finished 50.00%
# processing permno 82647 / finished 19.57%
# processing permno 82651 / finished 20.65%
# processing permno 79785 / finished 51.09%
# processing permno 82686 / finished 21.74%
# processing permno 79879 / finished 52.17%
# processing permno 82705 / finished 22.83%
# processing permno 82775 / finished 23.91%
# processing permno 79881 / finished 53.26%
# processing permno 82776 / finished 25.00%
# processing permno 82959 / finished 26.09%
# processing permno 79906 / finished 54.35%
# processing permno 83111 / finished 27.17%
# processing permno 79915 / finished 55.43%
# processing permno 83143 / finished 28.26%
# processing permno 79973 / finished 56.52%
# processing permno 80055 / finished 57.61%
# processing permno 83332 / finished 29.35%
# processing permno 80080 / finished 58.70%
# processing permno 83413 / finished 30.43%
# processing permno 83421 / finished 31.52%
# processing permno 80094 / finished 59.78%
# processing permno 80100 / finished 60.87%
# processing permno 83435 / finished 32.61%
# processing permno 80183 / finished 61.96%
# processing permno 83440 / finished 33.70%
# processing permno 83443 / finished 34.78%
# processing permno 80191 / finished 63.04%
# processing permno 83462 / finished 35.87%
# processing permno 83583 / finished 36.96%
# processing permno 80204 / finished 64.13%
# processing permno 83596 / finished 38.04%
# processing permno 83597 / finished 39.13%
# processing permno 80266 / finished 65.22%
# processing permno 83601 / finished 40.22%
# processing permno 80286 / finished 66.30%
# processing permno 80303 / finished 67.39%
# processing permno 83621 / finished 41.30%
# processing permno 80320 / finished 68.48%
# processing permno 83630 / finished 42.39%
# processing permno 80381 / finished 69.57%
# processing permno 83693 / finished 43.48%
# processing permno 83699 / finished 44.57%
# processing permno 80399 / finished 70.65%
# processing permno 83862 / finished 45.65%
# processing permno 83906 / finished 46.74%
# processing permno 80406 / finished 71.74%
# processing permno 80410 / finished 72.83%
# processing permno 80411 / finished 73.91%
# processing permno 83976 / finished 47.83%
# processing permno 80470 / finished 75.00%
# processing permno 80506 / finished 76.09%
# processing permno 80515 / finished 77.17%
# processing permno 83981 / finished 48.91%
# processing permno 83988 / finished 50.00%
# processing permno 84001 / finished 51.09%
# processing permno 80539 / finished 78.26%
# processing permno 84020 / finished 52.17%
# processing permno 84032 / finished 53.26%
# processing permno 80563 / finished 79.35%
# processing permno 84036 / finished 54.35%
# processing permno 84129 / finished 55.43%
# processing permno 80599 / finished 80.43%
# processing permno 80678 / finished 81.52%
# processing permno 80681 / finished 82.61%
# processing permno 84176 / finished 56.52%
# processing permno 80694 / finished 83.70%
# processing permno 80711 / finished 84.78%
# processing permno 84342 / finished 57.61%
# processing permno 80913 / finished 85.87%
# processing permno 84372 / finished 58.70%
# processing permno 81045 / finished 86.96%
# processing permno 84373 / finished 59.78%
# processing permno 81055 / finished 88.04%
# processing permno 84375 / finished 60.87%
# processing permno 81061 / finished 89.13%
# processing permno 84381 / finished 61.96%
# processing permno 81126 / finished 90.22%
# processing permno 84519 / finished 63.04%
# processing permno 81138 / finished 91.30%
# processing permno 84761 / finished 64.13%
# processing permno 81193 / finished 92.39%
# processing permno 81262 / finished 93.48%
# processing permno 81285 / finished 94.57%
# processing permno 84767 / finished 65.22%
# processing permno 81481 / finished 95.65%
# processing permno 84769 / finished 66.30%
# processing permno 81540 / finished 96.74%
# processing permno 84788 / finished 67.39%
# processing permno 81593 / finished 97.83%
# processing permno 85032 / finished 68.48%
# processing permno 85035 / finished 69.57%
# processing permno 81655 / finished 98.91%
# processing permno 85058 / finished 70.65%
# processing permno 81677 / finished 100.00%
# processing permno 85072 / finished 71.74%
# processing permno 86021 / finished 1.09%
# processing permno 85073 / finished 72.83%
# processing permno 85238 / finished 73.91%
# processing permno 85257 / finished 75.00%
# processing permno 86041 / finished 2.17%
# processing permno 86102 / finished 3.26%
# processing permno 85265 / finished 76.09%
# processing permno 86111 / finished 4.35%
# processing permno 85269 / finished 77.17%
# processing permno 86136 / finished 5.43%
# processing permno 85271 / finished 78.26%
# processing permno 86158 / finished 6.52%
# processing permno 85348 / finished 79.35%
# processing permno 86176 / finished 7.61%
# processing permno 86228 / finished 8.70%
# processing permno 85459 / finished 80.43%
# processing permno 86239 / finished 9.78%
# processing permno 85516 / finished 81.52%
# processing permno 85522 / finished 82.61%
# processing permno 86305 / finished 10.87%
# processing permno 85592 / finished 83.70%
# processing permno 86314 / finished 11.96%
# processing permno 85593 / finished 84.78%
# processing permno 86326 / finished 13.04%
# processing permno 86339 / finished 14.13%
# processing permno 85599 / finished 85.87%
# processing permno 85621 / finished 86.96%
# processing permno 86356 / finished 15.22%
# processing permno 85631 / finished 88.04%
# processing permno 86414 / finished 16.30%
# processing permno 86496 / finished 17.39%
# processing permno 86580 / finished 18.48%
# processing permno 85663 / finished 89.13%
# processing permno 86591 / finished 19.57%
# processing permno 86725 / finished 20.65%
# processing permno 85675 / finished 90.22%
# processing permno 86756 / finished 21.74%
# processing permno 86783 / finished 22.83%
# processing permno 85753 / finished 91.30%
# processing permno 86799 / finished 23.91%
# processing permno 85792 / finished 92.39%
# processing permno 86845 / finished 25.00%
# processing permno 85869 / finished 93.48%
# processing permno 86868 / finished 26.09%
# processing permno 85908 / finished 94.57%
# processing permno 86946 / finished 27.17%
# processing permno 85913 / finished 95.65%
# processing permno 86964 / finished 28.26%
# processing permno 85914 / finished 96.74%
# processing permno 86976 / finished 29.35%
# processing permno 86979 / finished 30.43%
# processing permno 85926 / finished 97.83%
# processing permno 86996 / finished 31.52%
# processing permno 85963 / finished 98.91%
# processing permno 87029 / finished 32.61%
# processing permno 85991 / finished 100.00%
# processing permno 87055 / finished 33.70%
# processing permno 89565 / finished 1.09%
# processing permno 89617 / finished 2.17%
# processing permno 87070 / finished 34.78%
# processing permno 89626 / finished 3.26%
# processing permno 87127 / finished 35.87%
# processing permno 87137 / finished 36.96%
# processing permno 89641 / finished 4.35%
# processing permno 89757 / finished 5.43%
# processing permno 87184 / finished 38.04%
# processing permno 89781 / finished 6.52%
# processing permno 87267 / finished 39.13%
# processing permno 89813 / finished 7.61%
# processing permno 89866 / finished 8.70%
# processing permno 87292 / finished 40.22%
# processing permno 89954 / finished 9.78%
# processing permno 87299 / finished 41.30%
# processing permno 90038 / finished 10.87%
# processing permno 87432 / finished 42.39%
# processing permno 90071 / finished 11.96%
# processing permno 90090 / finished 13.04%
# processing permno 87445 / finished 43.48%
# processing permno 90110 / finished 14.13%
# processing permno 87447 / finished 44.57%
# processing permno 90162 / finished 15.22%
# processing permno 90199 / finished 16.30%
# processing permno 87536 / finished 45.65%
# processing permno 87541 / finished 46.74%
# processing permno 90215 / finished 17.39%
# processing permno 87657 / finished 47.83%
# processing permno 90248 / finished 18.48%
# processing permno 90272 / finished 19.57%
# processing permno 87717 / finished 48.91%
# processing permno 90305 / finished 20.65%
# processing permno 90319 / finished 21.74%
# processing permno 87800 / finished 50.00%
# processing permno 90352 / finished 22.83%
# processing permno 87842 / finished 51.09%
# processing permno 90373 / finished 23.91%
# processing permno 88031 / finished 52.17%
# processing permno 90386 / finished 25.00%
# processing permno 90435 / finished 26.09%
# processing permno 90441 / finished 27.17%
# processing permno 88281 / finished 53.26%
# processing permno 90442 / finished 28.26%
# processing permno 90454 / finished 29.35%
# processing permno 88313 / finished 54.35%
# processing permno 90455 / finished 30.43%
# processing permno 88319 / finished 55.43%
# processing permno 90505 / finished 31.52%
# processing permno 88352 / finished 56.52%
# processing permno 90520 / finished 32.61%
# processing permno 88388 / finished 57.61%
# processing permno 90537 / finished 33.70%
# processing permno 88436 / finished 58.70%
# processing permno 88446 / finished 59.78%
# processing permno 90547 / finished 34.78%
# processing permno 90601 / finished 35.87%
# processing permno 88587 / finished 60.87%
# processing permno 88590 / finished 61.96%
# processing permno 90609 / finished 36.96%
# processing permno 88601 / finished 63.04%
# processing permno 88661 / finished 64.13%
# processing permno 90664 / finished 38.04%
# processing permno 88664 / finished 65.22%
# processing permno 90721 / finished 39.13%
# processing permno 90805 / finished 40.22%
# processing permno 88668 / finished 66.30%
# processing permno 90808 / finished 41.30%
# processing permno 90829 / finished 42.39%
# processing permno 88837 / finished 67.39%
# processing permno 90880 / finished 43.48%
# processing permno 88845 / finished 68.48%
# processing permno 90979 / finished 44.57%
# processing permno 88853 / finished 69.57%
# processing permno 90993 / finished 45.65%
# processing permno 91041 / finished 46.74%
# processing permno 88860 / finished 70.65%
# processing permno 91063 / finished 47.83%
# processing permno 88873 / finished 71.74%
# processing permno 91068 / finished 48.91%
# processing permno 91103 / finished 50.00%
# processing permno 88991 / finished 72.83%
# processing permno 91143 / finished 51.09%
# processing permno 89001 / finished 73.91%
# processing permno 89002 / finished 75.00%
# processing permno 91152 / finished 52.17%
# processing permno 91207 / finished 53.26%
# processing permno 89003 / finished 76.09%
# processing permno 91218 / finished 54.35%
# processing permno 91233 / finished 55.43%
# processing permno 89004 / finished 77.17%
# processing permno 91380 / finished 56.52%
# processing permno 89006 / finished 78.26%
# processing permno 91388 / finished 57.61%
# processing permno 91391 / finished 58.70%
# processing permno 91392 / finished 59.78%
# processing permno 89014 / finished 79.35%
# processing permno 91416 / finished 60.87%
# processing permno 89017 / finished 80.43%
# processing permno 91461 / finished 61.96%
# processing permno 89070 / finished 81.52%
# processing permno 91547 / finished 63.04%
# processing permno 91556 / finished 64.13%
# processing permno 89071 / finished 82.61%
# processing permno 89105 / finished 83.70%
# processing permno 91611 / finished 65.22%
# processing permno 89179 / finished 84.78%
# processing permno 91650 / finished 66.30%
# processing permno 89195 / finished 85.87%
# processing permno 91668 / finished 67.39%
# processing permno 91849 / finished 68.48%
# processing permno 89216 / finished 86.96%
# processing permno 91883 / finished 69.57%
# processing permno 91926 / finished 70.65%
# processing permno 89217 / finished 88.04%
# processing permno 91937 / finished 71.74%
# processing permno 89258 / finished 89.13%
# processing permno 92121 / finished 72.83%
# processing permno 92156 / finished 73.91%
# processing permno 89269 / finished 90.22%
# processing permno 92157 / finished 75.00%
# processing permno 92239 / finished 76.09%
# processing permno 89301 / finished 91.30%
# processing permno 92293 / finished 77.17%
# processing permno 89392 / finished 92.39%
# processing permno 92322 / finished 78.26%
# processing permno 89393 / finished 93.48%
# processing permno 92402 / finished 79.35%
# processing permno 92602 / finished 80.43%
# processing permno 89463 / finished 94.57%
# processing permno 89495 / finished 95.65%
# processing permno 92611 / finished 81.52%
# processing permno 89508 / finished 96.74%
# processing permno 92614 / finished 82.61%
# processing permno 89509 / finished 97.83%
# processing permno 92618 / finished 83.70%
# processing permno 92655 / finished 84.78%
# processing permno 89525 / finished 98.91%
# processing permno 89533 / finished 100.00%
# processing permno 92709 / finished 85.87%
# processing permno 92772 / finished 86.96%
# processing permno 92778 / finished 88.04%
# processing permno 92890 / finished 89.13%
# processing permno 92988 / finished 90.22%
# processing permno 93002 / finished 91.30%
# processing permno 93089 / finished 92.39%
# processing permno 93096 / finished 93.48%
# processing permno 93132 / finished 94.57%
# processing permno 93159 / finished 95.65%
# processing permno 93246 / finished 96.74%
# processing permno 93422 / finished 97.83%
# processing permno 93429 / finished 98.91%
# processing permno 93436 / finished 100.00%
# processing pd.concat

# %%
# process dataframe
crsp = crsp.dropna(subset=['zerotrade'])  # drop NA due to rolling
crsp = crsp.reset_index(drop=True)
crsp = crsp[['permno', 'date', 'zerotrade']]

with open('zerotrade.feather', 'wb') as f:
    feather.write_feather(crsp, f)
